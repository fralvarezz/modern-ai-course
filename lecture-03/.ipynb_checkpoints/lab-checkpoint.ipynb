# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/real-itu/modern-ai-course/blob/master/lecture-03/lab.ipynb)

# %% [markdown]
# # Lab 3 - Monte Carlo Tree Search
#
# In this exercise we will use the same game as in the previous exercise, namely, Connect 4.
# ([Connect 4](https://en.wikipedia.org/wiki/Connect_Four)). You should implement the MCTS algorithm to play the game.

# %% [markdown]
# As before, the game is implemented below. It will play a game where both players take random (legal) actions. The MAX player is represented with a X and the MIN player with an O. The MAX player starts. Execute the code.

# %%
import random
from copy import deepcopy
from typing import Sequence

NONE = '.'
MAX = 'X'
MIN = 'O'
COLS = 7
ROWS = 6
N_WIN = 4


class ArrayState:
    def __init__(self, board, heights, n_moves):
        self.board = board
        self.heights = heights
        self.n_moves = n_moves

    @staticmethod
    def init():
        board = [[NONE] * ROWS for _ in range(COLS)]
        return ArrayState(board, [0] * COLS, 0)


def result(state: ArrayState, action: int) -> ArrayState:
    """Insert in the given column."""
    assert 0 <= action < COLS, "action must be a column number"

    if state.heights[action] >= ROWS:
        raise Exception('Column is full')

    player = MAX if state.n_moves % 2 == 0 else MIN

    board = deepcopy(state.board)
    board[action][ROWS - state.heights[action] - 1] = player

    heights = deepcopy(state.heights)
    heights[action] += 1

    return ArrayState(board, heights, state.n_moves + 1)


def actions(state: ArrayState) -> Sequence[int]:
    return [i for i in range(COLS) if state.heights[i] < ROWS]


def branch_states(state: ArrayState) -> Sequence[ArrayState]:
    """get all reachable states from the current state:
        useful for MCTS
    """
    return [[result(state, a),a] for a in actions(state)]    

def utility(state: ArrayState) -> float:
    """Get the winner on the current board."""

    board = state.board

    def diagonalsPos():
        """Get positive diagonals, going from bottom-left to top-right."""
        for di in ([(j, i - j) for j in range(COLS)] for i in range(COLS + ROWS - 1)):
            yield [board[i][j] for i, j in di if i >= 0 and j >= 0 and i < COLS and j < ROWS]

    def diagonalsNeg():
        """Get negative diagonals, going from top-left to bottom-right."""
        for di in ([(j, i - COLS + j + 1) for j in range(COLS)] for i in range(COLS + ROWS - 1)):
            yield [board[i][j] for i, j in di if i >= 0 and j >= 0 and i < COLS and j < ROWS]

    lines = board + \
            list(zip(*board)) + \
            list(diagonalsNeg()) + \
            list(diagonalsPos())

    max_win = MAX * N_WIN
    min_win = MIN * N_WIN
    for line in lines:
        str_line = "".join(line)
        if max_win in str_line:
            return 1
        elif min_win in str_line:
            return -1
    return 0


def terminal_test(state: ArrayState) -> bool:
    return state.n_moves >= COLS * ROWS or utility(state) != 0


def printBoard(state: ArrayState):
    board = state.board
    """Print the board."""
    print('  '.join(map(str, range(COLS))))
    for y in range(ROWS):
        print('  '.join(str(board[x][y]) for x in range(COLS)))
    print()



s = ArrayState.init()
while not terminal_test(s):
    a = random.choice(actions(s))
    s = result(s, a)
    printBoard(s)
print(utility(s))

# %% [markdown]
# The last number 0, -1 or 1 is the utility or score of the game. 0 means it was a draw, 1 means MAX player won and -1 means MIN player won.

# %% [markdown]
# ### Exercise 1 (Transfer code from the previous exercise)
#
# Modify the code so that you can play manually as the MIN player against the random AI.

# %%
import random
from copy import deepcopy
from typing import Sequence

NONE = '.'
MAX = 'X'
MIN = 'O'
COLS = 7
ROWS = 6
N_WIN = 4


class ArrayState:
    def __init__(self, board, heights, n_moves):
        self.board = board
        self.heights = heights
        self.n_moves = n_moves

    @staticmethod
    def init():
        board = [[NONE] * ROWS for _ in range(COLS)]
        return ArrayState(board, [0] * COLS, 0)
    
    def __eq__(self, obj):
        return isinstance(obj, ArrayState) and self.board == obj.board


def result(state: ArrayState, action: int) -> ArrayState:
    """Insert in the given column."""
    assert 0 <= action < COLS, "action must be a column number"

    if state.heights[action] >= ROWS:
        raise Exception('Column is full')

    player = MAX if state.n_moves % 2 == 0 else MIN

    board = deepcopy(state.board)
    board[action][ROWS - state.heights[action] - 1] = player

    heights = deepcopy(state.heights)
    heights[action] += 1

    return ArrayState(board, heights, state.n_moves + 1)


def actions(state: ArrayState) -> Sequence[int]:
    return [i for i in range(COLS) if state.heights[i] < ROWS]


def branch_states(state: ArrayState) -> Sequence[ArrayState]:
    """get all reachable states from the current state:
        useful for MCTS
    """
    return [[result(state, a),a] for a in actions(state)]
    

def utility(state: ArrayState) -> float:
    """Get the winner on the current board."""

    board = state.board

    def diagonalsPos():
        """Get positive diagonals, going from bottom-left to top-right."""
        for di in ([(j, i - j) for j in range(COLS)] for i in range(COLS + ROWS - 1)):
            yield [board[i][j] for i, j in di if i >= 0 and j >= 0 and i < COLS and j < ROWS]

    def diagonalsNeg():
        """Get negative diagonals, going from top-left to bottom-right."""
        for di in ([(j, i - COLS + j + 1) for j in range(COLS)] for i in range(COLS + ROWS - 1)):
            yield [board[i][j] for i, j in di if i >= 0 and j >= 0 and i < COLS and j < ROWS]

    lines = board + \
            list(zip(*board)) + \
            list(diagonalsNeg()) + \
            list(diagonalsPos())

    max_win = MAX * N_WIN
    min_win = MIN * N_WIN
    for line in lines:
        str_line = "".join(line)
        if max_win in str_line:
            return 1
        elif min_win in str_line:
            return -1
    return 0


def terminal_test(state: ArrayState) -> bool:
    return state.n_moves >= COLS * ROWS or utility(state) != 0


def printBoard(state: ArrayState):
    board = state.board
    """Print the board."""
    print('  '.join(map(str, range(COLS))))
    for y in range(ROWS):
        print('  '.join(str(board[x][y]) for x in range(COLS)))
    print()

# %% [markdown]
# ### Exercise 2
# Implement the standard MCTS algorithm.

# %%
from abc import ABC, abstractmethod
from collections import defaultdict
import math
import time

class NodeState:
    def __init__(self, state, move, parent):
        self.state = state
        self.children = []
        self.parent = parent
        self.t = 0
        self.n = 0
        self.move = move
        
    def __str__(self):
        return "State with " + str(len(self.children))  + " children, with t: " + str(self.t) + " and n: " + str(self.n) + ". The move was: " + str(self.move)


class MCTS:
    "Monte Carlo tree searcher."
    
    def __init__(self, exploration_weight=1):
        self.path = []
        self.starting = None
        

    def choose(self, state, allowed_iters):
        "Choose a move in the game and execute it"
        
        self.starting = NodeState(state, 0, None)
        self._expand(self.starting)
        
        for i in range(allowed_iters):
            print("Iter: " + str(i))
            selected = self._select(self.starting)
            #print(selected)
            new_selected = self._expand(selected)
            #print(new_selected)
            reward = self.do_rollout(new_selected.state)
            self._backpropagate(self.path, reward)
        
        chosen_child = self._uct_select(self.starting.children)
        for i in self.starting.children:
            print(i)
        return chosen_child.move
    

    def do_rollout(self, state : ArrayState):
        "Train for one iteration."
        value = self._simulate(state)
        #print(value)
        return value
        

    def _select(self, state : NodeState):
        "Find an unexplored descendent of the `state`"
        if len(state.children) == 0:
            return state
        else:
            #print(len(state.children))
            selected = self._uct_select(state.children)
            self.path.append(selected)
            return self._select(selected)

    def _expand(self, state : NodeState):
        "Expand the `state` with all states reachable from it"
        if state.n == 0 and state!=self.starting:
            return state
        states = branch_states(state.state)
        for s in states:
            new_nodestate = NodeState(s[0], s[1], state)
            state.children.append(new_nodestate)
        self.path.append(state.children[0])
        return state.children[0]
            
    def _simulate(self, state : ArrayState):
        "Returns the reward for a random simulation (to completion) of the `state`"
        while not terminal_test(state):
            a = random.choice(actions(state))
            state = result(state, a)
        if utility(state) == 1:
            return 1
        else:
            return 0

    def _backpropagate(self, path, reward):
        "Send the reward back up to the ancestors of the leaf"
        for nodestate in path:
            nodestate.t += reward
            nodestate.n += 1
            #print("Updated nodestate, now t is " + str(nodestate.t))
            #print("Updated nodestate, now n is " + str(nodestate.n))
        path = []

    def _uct_select(self, children):
        "Select a child of state, balancing exploration & exploitation"
        #print(children)
        parent = children[0].parent
        if parent is None:
            return children[0]
        max_ucb = 0
        max_child = 0
        counter = 0
        #print("In this iteration:")
        for child in children:
            #print(child.n)
            #print(child.t)
            #print(parent.n)
            #print("maxchild: " + str(max_child))
            if child.n != 0:
                avg = child.t/child.n
            else: 
                avg = math.inf
            
            if avg != math.inf and parent.n != 0:
                ucb = avg + 2 * math.sqrt(math.log(parent.n)/child.n)
            else:
                ucb = math.inf
            #print("Ucb for child " + str(counter) + " was " + str(ucb))
            if ucb == math.inf:
                return children[counter]
            max_ucb = max(ucb,max_ucb)
            if max_ucb == ucb:
                max_child = counter
            counter = counter + 1
        
        return children[max_child]

# %% [markdown]
# ### Exercise 3
# Implement the loop where you play against your MCTS agent. Either train the agent at each step while you play against it, or pretrain it with more rollouts and play agaist it after training.

# %%
def train_model(state : ArrayState, num_rollouts : int):
    pass

# %%
s = ArrayState.init()
while not terminal_test(s):
    print(s.n_moves)
    if s.n_moves % 2 != 0:
        inp = int(input("What column do you want and dont trick me cause I am not checking for errors: "))
        a = actions(s)[inp]
        # a = random.choice(actions(s))
    else:
        mcts = MCTS()
        a = mcts.choose(s, 100)
        #a = random.choice(actions(s))

    s = result(s, a)
    printBoard(s)
print(utility(s))
# Out:
# 0
# Iter: 0
# maxchild: 0
# Iter: 1
# maxchild: 0
# Iter: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 6
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 7
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 8
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 9
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 10
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 11
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 12
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 13
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 14
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 15
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 16
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# Iter: 17
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# Iter: 18
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# Iter: 19
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# Iter: 20
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 21
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 22
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 23
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 24
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 25
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 26
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 27
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 28
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 29
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 30
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 31
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 32
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 33
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 34
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 35
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 36
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 37
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 38
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 39
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 40
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 41
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 42
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 43
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 44
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 45
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 46
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 47
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 48
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 49
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 50
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 51
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 52
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# Iter: 53
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# Iter: 54
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 55
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 56
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 57
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 58
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 59
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 60
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 61
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# Iter: 62
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# Iter: 63
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 64
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# Iter: 65
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 66
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 67
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 68
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 69
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 70
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 71
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 72
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 73
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 74
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 75
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 76
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 77
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 78
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 79
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 80
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 81
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 82
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 83
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 84
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 85
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 86
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 87
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 88
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 89
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# Iter: 90
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 91
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 92
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 93
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 94
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 95
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 96
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 97
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 98
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 99
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# 0  1  2  3  4  5  6
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# X  .  .  .  .  .  .
#
# 1
# What column do you want and dont trick me cause I am not checking for errors:  3
# 0  1  2  3  4  5  6
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# X  .  .  O  .  .  .
#
# 2
# Iter: 0
# maxchild: 0
# Iter: 1
# maxchild: 0
# Iter: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 6
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 7
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 8
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 9
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 10
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 11
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 12
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 13
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 14
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 15
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# Iter: 16
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# Iter: 17
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# Iter: 18
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 19
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 20
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 21
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 22
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# Iter: 23
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 24
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# Iter: 25
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 26
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 27
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 28
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 29
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 30
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 31
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 32
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 33
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 34
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 35
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 36
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 37
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 38
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 39
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 40
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 41
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 42
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 43
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 44
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 45
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# Iter: 46
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 47
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 48
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 49
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# Iter: 50
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 51
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 52
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# Iter: 53
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 54
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 55
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 56
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 57
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 58
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 59
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 60
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 61
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 62
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 63
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 64
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 65
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 66
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 67
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 68
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 69
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 70
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 71
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 72
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 73
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 74
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 75
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 76
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 77
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 78
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 79
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 80
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 81
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 82
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 83
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 84
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 85
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 86
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 87
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 88
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 89
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 90
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 91
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 92
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 93
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 94
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 95
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 96
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 97
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 98
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 99
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# 0  1  2  3  4  5  6
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# X  .  .  .  .  .  .
# X  .  .  O  .  .  .
#
# 3
# What column do you want and dont trick me cause I am not checking for errors:  3
# 0  1  2  3  4  5  6
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# .  .  .  .  .  .  .
# X  .  .  O  .  .  .
# X  .  .  O  .  .  .
#
# 4
# Iter: 0
# maxchild: 0
# Iter: 1
# maxchild: 0
# Iter: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 6
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 7
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 8
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 9
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 10
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 11
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 12
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 13
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 14
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 15
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 16
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# Iter: 17
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# Iter: 18
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 19
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# Iter: 20
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# Iter: 21
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 22
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 23
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 24
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 25
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 26
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 27
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 28
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 29
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 30
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 31
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 32
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 33
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 34
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 35
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 36
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 37
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 38
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# Iter: 39
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 40
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 41
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 42
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 43
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 44
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 45
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 46
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# Iter: 47
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# Iter: 48
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 49
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 50
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# Iter: 51
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 52
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 53
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 54
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# Iter: 55
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# Iter: 56
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# Iter: 57
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# Iter: 58
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# Iter: 59
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 60
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# Iter: 61
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 62
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 63
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 64
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 65
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 66
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 67
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 68
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 69
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# Iter: 70
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 71
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 72
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 73
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 74
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 75
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 76
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 77
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 78
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 79
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 80
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 81
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 82
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 83
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# ...
# maxchild: 3
# maxchild: 3
# Iter: 12
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 13
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# Iter: 14
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 15
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# Iter: 16
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# Iter: 17
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# Iter: 18
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# Iter: 19
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 20
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 21
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 22
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 23
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 24
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 25
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 26
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 27
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 28
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 29
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 30
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 31
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 32
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 33
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 34
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 35
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 36
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 37
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 38
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 39
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 40
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 41
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 42
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 43
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 44
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 45
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 46
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 47
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 48
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 49
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# Iter: 50
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 51
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 52
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 53
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 5
# Iter: 54
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 55
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 5
# Iter: 56
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 57
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 58
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 59
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 60
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# Iter: 61
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 62
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 63
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 64
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 65
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# Iter: 66
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# Iter: 67
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 5
# Iter: 68
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 5
# Iter: 69
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 5
# Iter: 70
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 71
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# Iter: 72
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 73
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 74
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 75
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 76
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 77
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 78
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 79
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 80
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 81
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# Iter: 82
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 5
# Iter: 83
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# Iter: 84
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 5
# maxchild: 0
# maxchild: 0
# Iter: 85
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# Iter: 86
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 87
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# Iter: 88
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# Iter: 89
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 90
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 91
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 92
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# Iter: 93
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# Iter: 94
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 3
# maxchild: 3
# maxchild: 3
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 95
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# Iter: 96
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# Iter: 97
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# Iter: 98
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 2
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# Iter: 99
# maxchild: 0
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 1
# maxchild: 1
# maxchild: 4
# maxchild: 4
# maxchild: 0
# maxchild: 0
# maxchild: 1
# maxchild: 2
# maxchild: 3
# maxchild: 4
# maxchild: 4
# maxchild: 0
# 0  1  2  3  4  5  6
# .  .  .  .  .  .  .
# X  .  .  .  .  .  .
# O  .  .  .  .  .  .
# X  .  .  .  .  .  .
# X  .  .  O  .  .  .
# X  .  .  O  .  .  .
#
# 7

# %% [markdown]
# ### Exercise 4
#
# Add move ordering. The middle columns are often "better" since there's more winning positions that contain them. Increase the probability to choose middle columns when randomly executing rollouts: [3,2,4,1,5,0,6]. See if your connect4 AI can beat you.

# %% [markdown]
# ### Exercise 5 - Optional
#
# Pit your MCTS agent against the one from the previous exercise.
# * Which one wins more often?
# * Which one takes more time to run per step once it is at a point that it can beat you?
